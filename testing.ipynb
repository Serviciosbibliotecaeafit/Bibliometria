# %%
import time
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.support.wait import WebDriverWait
from datetime import datetime

# %%
import time
import os.path
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options

# %%
chrome_options = Options()
chrome_options.add_argument("--headless") # Ensure GUI is off
chrome_options.add_argument("--no-sandbox")

# %%
# Set path to chromedriver as per your configuration
homedir = os.path.expanduser("~")
webdriver_service = Service(f"{homedir}/chromedriver/stable/chromedriver")

# %%
# Choose Chrome Browser
browser = webdriver.Chrome(service=webdriver_service, options=chrome_options)

# %%
browser.get("https://cloudbytes.dev")

# %%
description = browser.find_element(By.NAME, "description").get_attribute("content")
print(f"{description}")
# Out:
#  CloudBytes/dev>: Programming on Steroids | Code snippets, lessons, tutorials, and more.

# %%
browser.quit()

# %%
def log_in(driver, log_url, email, password):
    driver.get(log_url)
    email_box = driver.find_element(By.ID, 'bdd-email')
    email_box.send_keys(email)
    continue_button = driver.find_element(By.ID, 'bdd-els-searchBtn')
    WebDriverWait(driver, timeout=10).until(button_available)
    continue_button.click()
    password_box = driver.find_element(By.ID, 'bdd-password')
    password_box.send_keys(password)
    log_in_button = driver.find_element(By.ID, 'bdd-elsPrimaryBtn')
    log_in_button.click()

def button_available(driver):
    return driver.find_element(By.ID, 'bdd-els-searchBtn').is_enabled()

# %%
# path of the chromedriver we have just downloaded
# PATH = r"D:\chromedriver"
# driver = webdriver.Chrome(PATH)
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

log_url = 'https://id.elsevier.com/as/authorization.oauth2?platSite=SC%2Fscopus&ui_locales=en-US&scope=openid+profile+email+els_auth_info+els_analytics_info+urn%3Acom%3Aelsevier%3Aidp%3Apolicy%3Aproduct%3Ainst_assoc&response_type=code&redirect_uri=https%3A%2F%2Fwww.scopus.com%2Fauthredirect.uri%3FtxGid%3D57c43acf0d806007ed19bbbaeec838ad&state=checkAccessLogin%7CtxId%3D00198FF4CF3BA6CD763C25007BA8B4E9.i-02c85120f7972130d%3A6&authType=SINGLE_SIGN_IN&prompt=login&client_id=SCOPUS'

url = 'https://www.scopus.com/record/display.uri?eid=2-s2.0-85084148845&doi=10.1007%2fs11524-020-00438-6&origin=inward&txGid=189d18a69d67efbe79c67ed7d90b87cc'

log_in(driver, log_url, 'jmduarteq@eafit.edu.co', 'Claudia1000636304')

# to open the url in the browser
driver.get(url)

Xpaths = {
        'Autores'   :   '/html/body/div/div/div[1]/div[2]/div/div[3]/div[3]/div/div[1]/div[2]/micro-ui/scopus-document-details-page/div/article/div[2]/section/div[3]/div/ul',
        'Titulo'    :   '/html/body/div/div/div[1]/div[2]/div/div[3]/div[3]/div/div[1]/div[2]/micro-ui/scopus-document-details-page/div/article/div[2]/section/div[1]/div/h2[1]/span',
        'Nombre_Publicación'    :   '/html/body/div/div/div[1]/div[2]/div/div[3]/div[3]/div/div[1]/div[2]/micro-ui/scopus-document-details-page/div/article/div[1]/div/div/span[1]/a/span/strong/em',
        'Tipo_Documento'    :   '/html/body/div/div/div[1]/div[2]/div/div[3]/div[3]/div/div[1]/div[2]/micro-ui/scopus-document-details-page/div/article/div[2]/aside/div/div/div/dl[1]/dd',
        'Idioma'    :   '/html/body/div/div/div[1]/div[2]/div/div[3]/div[3]/div/div[1]/div[2]/micro-ui/scopus-document-details-page/div/article/div[2]/aside/div/div/div/els-collapsible-panel/section/div/div/dl[2]/dd',
        'Resumen'   :   '/html/body/div/div/div[1]/div[2]/div/div[3]/div[3]/div/div[1]/div[2]/micro-ui/scopus-document-details-page/div/article/div[3]/section/div/div[1]/p/span',
        'Filiación_Autor'   :   '/html/body/div/div/div[1]/div[2]/div/div[3]/div[3]/div/div[1]/div[2]/micro-ui/scopus-document-details-page/div/article/div[2]/section/div[3]/div/div/ul',
        'Referencias_Citadas'   :   '/html/body/div/div/div[1]/div[2]/div/div[3]/div[3]/div/div[1]/div[2]/div[2]/div/section/div/form/table',
        'Total_Citas'   : '/html/body/div/div/div[1]/div[2]/div/div[3]/div[3]/div/div[1]/div[2]/div[2]/div/section/div/form/div/div[2]/ul/li[1]/h4',
        'País_Filiación_Autor'  :   '/html/body/div/div/div[1]/div[2]/div/div[3]/div[3]/div/div[1]/div[2]/micro-ui/scopus-document-details-page/div/article/div[2]/section/div[3]',
        'Año'   :   '/html/body/div/div/div[1]/div[2]/div/div[3]/div[3]/div/div[1]/div[2]/micro-ui/scopus-document-details-page/div/article/div[1]/div/div/span[3]',
        'Volumen'   :   '/html/body/div/div/div[1]/div[2]/div/div[3]/div[3]/div/div[1]/div[2]/micro-ui/scopus-document-details-page/div/article/div[1]/div/div/span[2]',
        'Número'    :   '/html/body/div/div/div[1]/div[2]/div/div[3]/div[3]/div/div[1]/div[2]/micro-ui/scopus-document-details-page/div/article/div[1]/div/div/span[2]',
        'DOI_Enlace_texto_completo' :   '/html/body/div/div/div[1]/div[2]/div/div[3]/div[3]/div/div[1]/div[2]/micro-ui/scopus-document-details-page/div/article/div[2]/aside/div/div/div/dl[4]/dd'}

headers = [
        'Autores',
        'Titulo',
        'Nombre_Publicación',
        'Tipo_Documento',
        'Idioma',
        'Resumen',
        'Filiación_Autor',
        'Referencias_Citadas',
        'Total_Citas',
        'País_Filiación_Autor',
        'Año',
        'Volumen',
        'Número',
        'DOI_Enlace_texto_completo']

output = {}

view_more_button = WebDriverWait(driver, timeout=10).until(
        lambda d: d.find_element(By.ID, "show-additional-source-info")
)
view_more_button.click()

for tipo in headers:
    try:
        link = driver.find_element(By.XPATH, Xpaths[tipo])
        output[tipo] = link.text
        if tipo == 'Autores': continue
        print(tipo+' : '+link.text)
    except:
        print(tipo)

driver.close()
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Cell In[13], line 4
#       1 # path of the chromedriver we have just downloaded
#       2 # PATH = r"D:\chromedriver"
#       3 # driver = webdriver.Chrome(PATH)
# ----> 4 driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
#       6 log_url = 'https://id.elsevier.com/as/authorization.oauth2?platSite=SC%2Fscopus&ui_locales=en-US&scope=openid+profile+email+els_auth_info+els_analytics_info+urn%3Acom%3Aelsevier%3Aidp%3Apolicy%3Aproduct%3Ainst_assoc&response_type=code&redirect_uri=https%3A%2F%2Fwww.scopus.com%2Fauthredirect.uri%3FtxGid%3D57c43acf0d806007ed19bbbaeec838ad&state=checkAccessLogin%7CtxId%3D00198FF4CF3BA6CD763C25007BA8B4E9.i-02c85120f7972130d%3A6&authType=SINGLE_SIGN_IN&prompt=login&client_id=SCOPUS'
# ...

# %%
import selenium_methods as sm
#from utilities import * # Archivo con diccionarios
import numpy as np
import pandas as pd

# Paths
dataPath = 'output/'
dataBases = ['LENS', 'SCIELO', 'SCOPUS', 'WOS']
# import data
data_AL = []
data_BR = []
for base in dataBases:
    data_AL.append(pd.read_csv(dataPath+base+'_AL.csv',sep=','))
    data_BR.append(pd.read_csv(dataPath+base+'_BR.csv',sep=','))

# %%
data_AL[2].shape
# Out:
# (252, 55)

# %%
import selenium_methods as sm
#from utilities import * # Archivo con diccionarios
import numpy as np
import pandas as pd

webData = pd.read_csv("output.csv", sep=',')

# %%
webData.columns
# Out:
# Index(['Unnamed: 0', 'Autores', 'Titulo', 'Nombre_Publicación',
#        'Tipo_Documento', 'Idioma', 'Resumen', 'Filiación_Autor',
#        'Referencias_Citadas', 'Total_Citas', 'País_Filiación_Autor', 'Año',
#        'Volumen', 'Número', 'DOI_Enlace_texto_completo',
#        'Pais_Filiación_Autor'],
#       dtype='object')

# %%
import norm_methods as norm

data = webData['Número'].values
out = norm.Numero_scopus({'Número':data})

# %%
webData['Número'].values
# Out:
# array(['1', '4', '1396', '8', '6', '100', '100', '100', '100', 'S4', 'S4',
#        '6', '13', '1', '3', '4', '60', '1', '51', '2', '1', '1', 'S1',
#        '1', '1', '115', '6', '1', '173', 'Not Found', 'S5', 'Not Found',
#        'Not Found', '32', 'Not Found', 'Not Found', '2', '12022', '35',
#        '35', '1', '99', 'Not Found', '1', 'Not Found', 'E', 'Not Found',
#        '2', '4', 'Not Found', '14', '2', '2', '113', 'Not Found',
#        'Not Found', '1', 'Not Found', '1', '1', '83', '1', '4', '1', '13',
#        '31', '11', '7', 'S2', '19', '80130', '9', 'S', 'S', '291', '34',
#        '2', '90', '95', '95', '4', 'Not Found', 'Not Found', '2', '107',
#        'Not Found', 'Not Found', '62', '2', '1', '200', '1', '1', '1',
#        '2', 'Not Found', '87', '3', '2', 'S2'], dtype=object)

# %%
webData
# Out:
#     Unnamed: 0                         Autores  \
# 0            0                    Rusca, Bruno
# 1            1         Amesquita, Fidel Edgard
# 2            2      Velásquez, Alejandro Gómez
# 3            3  Palacio Sprockel, Lilia Esther
# 4            4        Mora, José Fabián Molina
# ..         ...                             ...
# 95          95    Melo, Norma Angelica Pedraza
# 96          96             Vega, Paul Villegas
# 97          97        Varas, Cristian Pliscoff
# 98          98                  Mousa, Mohamed
# 99          99        Mora, José Fabián Molina
#
#                                                Titulo  \
# 0   Happy birthday, Mr. Public officer! About the ...
# 1   La tecnología usada como arma Para vencer a la...
# 2   Professional services contracts in the colombi...
# 3   Innovation in educational management: actors a...
# 4   PROTECTION FOR TEACHERS OF PUBLIC AND PRIVATE ...
# ..                                                ...
# ...

# %%
webData['Titulo'].values[31]
# Out:
# 'Becoming neoliberal policy subjects: Staff members’ discursive practices about school climate in Chile'

# %%
webData['DOI_Enlace_texto_completo'].values[0]
# Out:
# '10.1590/2317-6172202104'
